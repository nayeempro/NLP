# %%
pip install nltk
# Out:
# Collecting nltk
#   Downloading nltk-3.9.1-py3-none-any.whl (1.5 MB)
#                                               0.0/1.5 MB ? eta -:--:--
#      -                                        0.0/1.5 MB 991.0 kB/s eta 0:00:02
#      -                                        0.1/1.5 MB 825.8 kB/s eta 0:00:02
#      --                                       0.1/1.5 MB 871.5 kB/s eta 0:00:02
#      --                                       0.1/1.5 MB 871.5 kB/s eta 0:00:02
#      ---                                      0.1/1.5 MB 607.9 kB/s eta 0:00:03
#      -----                                    0.2/1.5 MB 811.5 kB/s eta 0:00:02
#      -------                                  0.3/1.5 MB 842.9 kB/s eta 0:00:02
#      ----------                               0.4/1.5 MB 1.1 MB/s eta 0:00:02
#      ------------                             0.5/1.5 MB 1.1 MB/s eta 0:00:01
#      ----------------                         0.6/1.5 MB 1.3 MB/s eta 0:00:01
#      ------------------                       0.7/1.5 MB 1.4 MB/s eta 0:00:01
#      -------------------                      0.7/1.5 MB 1.4 MB/s eta 0:00:01
#      --------------------                     0.8/1.5 MB 1.3 MB/s eta 0:00:01
#      ---------------------                    0.8/1.5 MB 1.2 MB/s eta 0:00:01
#      -----------------------                  0.9/1.5 MB 1.3 MB/s eta 0:00:01
#      --------------------------               1.0/1.5 MB 1.4 MB/s eta 0:00:01
#      -----------------------------            1.1/1.5 MB 1.4 MB/s eta 0:00:01
#      -------------------------------          1.2/1.5 MB 1.4 MB/s eta 0:00:01
#      -----------------------------------      1.3/1.5 MB 1.5 MB/s eta 0:00:01
#      ---------------------------------------- 1.5/1.5 MB 1.6 MB/s eta 0:00:00
# Collecting click (from nltk)
#   Downloading click-8.1.8-py3-none-any.whl (98 kB)
#                                               0.0/98.2 kB ? eta -:--:--
#      ---------------------------------------- 98.2/98.2 kB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: joblib in c:\users\asus\miniconda3\lib\site-packages (from nltk) (1.4.2)
# Collecting regex>=2021.8.3 (from nltk)
#   Downloading regex-2024.11.6-cp311-cp311-win_amd64.whl (274 kB)
#                                               0.0/274.1 kB ? eta -:--:--
#      --------                                61.4/274.1 kB 1.7 MB/s eta 0:00:01
#      ----------------------------------     245.8/274.1 kB 2.5 MB/s eta 0:00:01
#      -------------------------------------- 274.1/274.1 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in c:\users\asus\miniconda3\lib\site-packages (from nltk) (4.65.0)
# Requirement already satisfied: colorama in c:\users\asus\miniconda3\lib\site-packages (from click->nltk) (0.4.6)
# Installing collected packages: regex, click, nltk
# Successfully installed click-8.1.8 nltk-3.9.1 regex-2024.11.6
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_word = set(stopwords.words('english'))
stop_word
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she'd",
#  "she'll",
#  "she's",
#  'should',
#  "should've",
#  'shouldn',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  "they'd",
#  "they'll",
#  "they're",
#  "they've",
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  "we'd",
#  "we'll",
#  "we're",
#  "we've",
#  'were',
#  'weren',
#  "weren't",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
import pandas as pd
data = {'Bangladesh': ["Bangladesh is a South Asian country known for its rich culture, rapid economic growth, and resilience. It has a strong textile industry, vibrant heritage, and the world's largest mangrove forest, the Sundarbans."
],
'Nepal': ["Nepal is a South Asian country known for its stunning Himalayas, including Mount Everest. It has a rich cultural heritage, diverse traditions, and is home to Lumbini, the birthplace of Buddha."]
}
df = pd.DataFrame(data)
df
# Out:
#                                           Bangladesh  \
# 0  Bangladesh is a South Asian country known for ...
#
#                                                Nepal
# 0  Nepal is a South Asian country known for its s...

# %%
#remove stop word and join every word by ' '(space)
df["Bangladesh_clean"] = df["Bangladesh"].apply(lambda x: ' '.join([word for word in x.split() if word.lower() not in stop_word]))
df["Bangladesh_clean"]
# Out:
# 0    Bangladesh South Asian country known rich cult...
# Name: Bangladesh_clean, dtype: object
